# %%
import os

# Disable XLA
os.environ["TF_XLA_FLAGS"] = "--tf_xla_enable_xla_devices=false"
os.environ["XLA_FLAGS"] = "--xla_gpu_strict_conv_algorithm_picker=false"

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_DETERMINISTIC_OPS"] = "1"

# Disable CuDNN autotune
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
os.environ["TF_CUDNN_USE_AUTOTUNE"] = "0"

# %%
import tensorflow as tf
tf.random.set_seed(1)

from tensorflow import keras
from tensorflow.keras import layers

print("TF version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train[..., None] / 255.0
x_test  = x_test[..., None] / 255.0

model = keras.Sequential([
    layers.Input(shape=(28, 28, 1)),
    layers.Conv2D(32, 3, activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation="relu"),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense(10, activation="softmax"),
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()

model.fit(x_train, y_train, batch_size=128, epochs=3, validation_split=0.1)
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test loss:", test_loss, "Test acc:", test_acc)
# Out:
# 2025-12-02 11:25:45.320237: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TF version: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764642347.612748   36820 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9703 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3
# 2025-12-02 11:25:49.351828: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-12-02 11:25:48.303855: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-12-02 11:25:48.603461: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at conv_ops_fused_impl.h:683 : UNKNOWN: <unknown cudnn status: 5003>
# in external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc(5308): 'status'
# 2025-12-02 11:25:48.603531: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: UNKNOWN: <unknown cudnn status: 5003>
# in external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc(5308): 'status'
# 	 [[{{function_node __inference_one_step_on_data_1864}}{{node sequential_1/conv2d_1/Relu}}]]
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[2], line 33
#      25 model.compile(
#      26     optimizer="adam",
#      27     loss="sparse_categorical_crossentropy",
#      28     metrics=["accuracy"],
#      29 )
#      31 model.summary()
# ---> 33 model.fit(x_train, y_train, batch_size=128, epochs=3, validation_split=0.1)
#      34 test_loss, test_acc = model.evaluate(x_test, y_test)
#      35 print("Test loss:", test_loss, "Test acc:", test_acc)
#
# File ~/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# UnknownError: Graph execution error:
#
# Detected at node sequential_1/conv2d_1/Relu defined at (most recent call last):
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_36820/3553623828.py", line 33, in <module>
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 399, in fit
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 241, in function
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 154, in multi_step_on_iterator
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 134, in one_step_on_data
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 59, in train_step
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/models/sequential.py", line 220, in call
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/models/functional.py", line 183, in call
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/ops/function.py", line 206, in _run_through_graph
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/models/functional.py", line 644, in call
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py", line 263, in call
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/activations/activations.py", line 47, in relu
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/activations/activations.py", line 101, in static_call
#
#   File "/home/nampluskr/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py", line 15, in relu
#
# <unknown cudnn status: 5003>
# in external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc(5308): 'status'
# 	 [[{{node sequential_1/conv2d_1/Relu}}]] [Op:__inference_multi_step_on_iterator_1929]
